# %%
from bing_image_downloader import downloader
import pandas as pd

# %%
df = pd.read_csv("food_new.csv")

# %%
df.head()
# Out:
#                 name                                        ingredients  \
# 0          Adhirasam   Rice flour, jaggery, ghee, vegetable oil, elachi
# 1          Aloo gobi  Cauliflower, potato, garam masala, turmeric, c...
# 2         Aloo matar  Potato, peas, chillies, ginger, garam masala, ...
# 3         Aloo methi      Potato, fenugreek leaves, chillies, salt, oil
# 4  Aloo shimla mirch  Potato, shimla mirch, garam masala, amchur pow...
#
#          diet  prep_time  cook_time flavor_profile       course        state  \
# 0  vegetarian         10         50          sweet      dessert  West Bengal
# 1  vegetarian         10         20          spicy  main course       Punjab
# 2  vegetarian          5         40          spicy  main course       Punjab
# 3  vegetarian         10         40         bitter  main course       Punjab
# 4  vegetarian         10         40          spicy  main course       Punjab
#
#   region                                            img_url
# ...

# %%
food = list(df["name"])

# %%
print(food)
# Out:
# ['Adhirasam', 'Aloo gobi', 'Aloo matar', 'Aloo methi', 'Aloo shimla mirch', 'Aloo tikki', 'Alu Pitika', 'Amti', 'Anarsa', 'Ariselu', 'Attu', 'Avial', 'Baingan Fry', 'Bajri no rotlo', 'Balu shahi', 'Bandar laddu', 'Basundi', 'Bebinca', 'Bengena Pitika', 'Bhakri', 'Bhatura', 'Bhindi masala', 'Bilahi Maas', 'Biryani', 'Bisi bele bath', 'Black rice', 'Bombil fry', 'Boondi', 'Bora Sawul', 'Brown Rice', 'Butter chicken', 'Chak Hao Kheer', 'Chakali', 'Cham cham', 'Chana masala', 'Chapati', 'Cheera Doi', 'Chevdo', 'Chhena jalebi', 'Chhena kheeri', 'Chhena poda', 'Chicken razala', 'Chicken Tikka', 'Chicken Tikka masala', 'Chicken Varuval', 'Chikki', 'Chingri Bhape', 'Chingri malai curry', 'Chole bhature', 'Chorafali', 'Churma Ladoo', 'Coconut vadi', 'Copra paak', 'Currivepillai sadam ', 'Daal baati churma', 'Daal Dhokli', 'Daal puri', 'Dahi vada', 'Dal makhani ', 'Dal tadka', 'Dalithoy', 'Dharwad pedha', 'Dhokla', 'Dhondas', 'Doodhpak', 'Dosa', 'Double ka meetha', 'Dudhi halwa', 'Dum aloo', '
# ...

# %%
len(food)
# Out:
# 255

# %%
food1 = food[:127]
food2 = food[127:]

# %%
print(food2)
# Out:
# ['Kulfi falooda', 'Kumol Sawul', 'Kutchi dabeli', 'Kuzhakkattai', 'Kuzhambu', 'Kuzhi paniyaram', 'Laapsi', 'Laddu', 'Lassi', 'Lauki ke kofte', 'Lauki ki subji', 'Ledikeni', 'Lilva Kachori', 'Litti chokha', 'Luchi', 'Lyangcha', 'Maach Jhol', 'Mag Dhokli', 'Mahim halwa', 'Makki di roti sarson da saag', 'Malapua', 'Masala Dosa', 'Masor Koni', 'Masor tenga', 'Mawa Bati', 'Methi na Gota', 'Mihidana', 'Mishti Chholar Dal', 'Misi roti', 'Misti doi', 'Modak', 'Mohanthal', 'Mushroom do pyaza', 'Mushroom matar', 'Muthiya', 'Mysore pak', 'Naan', 'Namakpara', 'Nankhatai', 'Navrattan korma', 'Obbattu holige', 'Pachadi', 'Pakhala', 'Palak paneer', 'Palathalikalu', 'Paneer butter masala', 'Paneer tikka masala', 'Pani Pitha', 'Pani puri', 'Paniyaram', 'Panjeeri', 'Pantua', 'Papad', 'Papadum', 'Paratha', 'Paravannam', 'Paruppu sadam', 'Patra', 'Pattor', 'Pav Bhaji', 'Payasam', 'Payokh', 'Pesarattu', 'Petha', 'Phirni', 'Pinaca', 'Pindi chana', 'Pithe', 'Poha', 'Pongal', 'Poornalu', 'Pootharekulu', 'Po
# ...

# %%
print(food1)
# Out:
# ['Konir Dom', 'Kootu', 'Kos kootu', 'Koshambri', 'Koshimbir', 'Kothamali sadam']

# %%
food1 = food1[1:]

# %%
for foodItem in food1:
    downloader.download(
    foodItem,
    limit=200,
    output_dir="dataset",
    adult_filter_off=True,
    force_replace=False,
    timeout=60,
    verbose=False,
)
# Out:
# [%] Downloading Images to c:\Users\mk020\Desktop\Projects\IndianFoodRecognition\Model\dataset\Konir Dom
# [!] Issue getting: http://www.spicydinners.com/wp-content/uploads/2019/02/Konir-Dom-760x400.jpg
# [!] Error:: HTTP Error 404: Not Found
# [Error]Invalid image, not saving https://themustardspecialist.files.wordpress.com/2023/01/aloo-konir-dum.jpg
#
# [!] Issue getting: https://themustardspecialist.files.wordpress.com/2023/01/aloo-konir-dum.jpg
# [!] Error:: Invalid image, not saving https://themustardspecialist.files.wordpress.com/2023/01/aloo-konir-dum.jpg
#
# [!] Issue getting: https://www.power-publishers.com/wp-content/uploads/2016/04/konir kandokarkhana (1).jpg
# [!] Error:: URL can't contain control characters. '/wp-content/uploads/2016/04/konir kandokarkhana (1).jpg' (found at least ' ')
# [Error]Invalid image, not saving https://www.parlament.gv.at/WWER/PAD_00910/2100734_500.jpg
#
# [!] Issue getting: https://www.parlament.gv.at/WWER/PAD_00910/2100734_500.jpg
# ...
