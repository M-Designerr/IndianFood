# %%
data = {'Adhirasam': 0,
 'Aloo gobi': 1,
 'Aloo matar': 2,
 'Aloo methi': 3,
 'Aloo shimla mirch': 4,
 'Aloo tikki': 5,
 'Alu Pitika': 6,
 'Amti': 7,
 'Anarsa': 8,
 'Ariselu': 9,
 'Avial': 10,
 'Baingan Fry': 11,
 'Bajri no rotlo': 12,
 'Balu shahi': 13,
 'Bandar laddu': 14,
 'Basundi': 15,
 'Bebinca': 16,
 'Bhakri': 17,
 'Bhatura': 18,
 'Bhindi masala': 19,
 'Biryani': 20,
 'Bisi bele bath': 21,
 'Black rice': 22,
 'Bombil fry': 23,
 'Brown Rice': 24,
 'Butter chicken': 25,
 'Chak Hao Kheer': 26,
 'Chakali': 27,
 'Cham cham': 28,
 'Chana masala': 29,
 'Chapati': 30,
 'Chevdo': 31,
 'Chhena jalebi': 32,
 'Chhena kheeri': 33,
 'Chhena poda': 34,
 'Chicken Tikka': 35,
 'Chicken Tikka masala': 36,
 'Chicken Varuval': 37,
 'Chicken razala': 38,
 'Chikki': 39,
 'Chingri Bhape': 40,
 'Chingri malai curry': 41,
 'Chole bhature': 42,
 'Chorafali': 43,
 'Churma Ladoo': 44,
 'Daal Dhokli': 45,
 'Daal baati churma': 46,
 'Daal puri': 47,
 'Dahi vada': 48,
 'Dal Makhani': 49,
 'Dal tadka': 50,
 'Dalithoy': 51,
 'Dharwad pedha': 52,
 'Dhokla': 53,
 'Doodhpak': 54,
 'Dosa': 55,
 'Double ka meetha': 56,
 'Dudhi halwa': 57,
 'Dum aloo': 58,
 'Farsi Puri': 59,
 'Gajar ka halwa': 60,
 'Gatta curry': 61,
 'Ghevar': 62,
 'Gud papdi': 63,
 'Gulab jamun': 64,
 'Halvasan': 65,
 'Idiappam': 66,
 'Idli': 67,
 'Imarti': 68,
 'Jalebi': 69,
 'Jeera Aloo': 70,
 'Kaara kozhambu': 71,
 'Kabiraji': 72,
 'Kachori': 73,
 'Kadai paneer': 74,
 'Kadhi pakoda': 75,
 'Kajjikaya': 76,
 'Kaju katli': 77,
 'Kakinada khaja': 78,
 'Kalakand': 79,
 'Karela bharta': 80,
 'Keerai kootu': 81,
 'Keerai masiyal': 82,
 'Keerai poriyal': 83,
 'Keerai sadam': 84,
 'Khakhra': 85,
 'Khaman': 86,
 'Khandvi': 87,
 'Kheer': 88,
 'Khichdi': 89,
 'Khichu': 90,
 'Khorisa': 91,
 'Kofta': 92,
 'Koldil Chicken': 93,
 'Kombdi vade': 94,
 'Kootu': 95,
 'Koshambri': 96,
 'Koshimbir': 97,
 'Kothamali sadam': 98,
 'Kuzhambu': 99,
 'Kuzhi paniyaram': 100,
 'Laddu': 101,
 'Lassi': 102,
 'Lauki ke kofte': 103,
 'Lauki ki subji': 104,
 'Lilva Kachori': 105,
 'Litti chokha': 106,
 'Luchi': 107,
 'Lyangcha': 108,
 'Maach Jhol': 109,
 'Mag Dhokli': 110,
 'Mahim halwa': 111,
 'Makki di roti sarson da saag': 112,
 'Malapua': 113,
 'Masala Dosa': 114,
 'Masor tenga': 115,
 'Mawa Bati': 116,
 'Methi na Gota': 117,
 'Mihidana': 118,
 'Misi roti': 119,
 'Misti doi': 120,
 'Modak': 121,
 'Mohanthal': 122,
 'Mushroom do pyaza': 123,
 'Mushroom matar': 124,
 'Muthiya': 125,
 'Mysore pak': 126,
 'Naan': 127,
 'Namakpara': 128,
 'Nankhatai': 129,
 'Navrattan korma': 130,
 'Palak paneer': 131,
 'Paneer butter masala': 132,
 'Paneer tikka masala': 133,
 'Pani puri': 134,
 'Panjeeri': 135,
 'Papad': 136,
 'Paruppu sadam': 137,
 'Pav Bhaji': 138,
 'Petha': 139,
 'Phirni': 140,
 'Pindi chana': 141,
 'Poha': 142,
 'Pongal': 143,
 'Poornalu': 144,
 'Pootharekulu': 145,
 'Poriyal': 146,
 'Pork Bharta': 147,
 'Prawn malai curry': 148,
 'Puli sadam': 149,
 'Puri Bhaji': 150,
 'Puttu': 151,
 'Qubani ka meetha': 152,
 'Rabri': 153,
 'Rajma chaval': 154,
 'Ras malai': 155,
 'Rasabali': 156,
 'Rasam': 157,
 'Rasgulla': 158,
 'Red Rice': 159,
 'Rongi': 160,
 'Sabudana Khichadi': 161,
 'Sambar': 162,
 'Samosa': 163,
 'Sandesh': 164,
 'Sandige': 165,
 'Sattu ki roti': 166,
 'Sev khamani': 167,
 'Sev tameta': 168,
 'Sevai': 169,
 'Shahi paneer': 170,
 'Shahi tukra': 171,
 'Shankarpali': 172,
 'Sheer khurma': 173,
 'Sheera': 174,
 'Shrikhand': 175,
 'Shufta': 176,
 'Shukto': 177,
 'Singori': 178,
 'Sohan papdi': 179,
 'Sukhdi': 180,
 'Surnoli': 181,
 'Sutar feni': 182,
 'Tandoori Chicken': 183,
 'Tandoori Fish Tikka': 184,
 'Thalipeeth': 185,
 'Thayir sadam': 186,
 'Theeyal': 187,
 'Thepla': 188,
 'Til Pitha': 189,
 'Turiya Patra Vatana sabji': 190,
 'Undhiyu': 191,
 'Unni Appam': 192,
 'Upma': 193,
 'Uttapam': 194,
 'Vada': 195,
 'Veg Kolhapuri': 196,
 'Vegetable jalfrezi': 197,
 'Vindaloo': 198,
 'Zunka': 199}

# Create a dictionary in the desired format for all items.
category = {}
for item, category_id in data.items():
    formatted_item = item.lower().replace(' ', '_')
    category[category_id] = [formatted_item, item]

print(category)
# Out:
# {0: ['adhirasam', 'Adhirasam'], 1: ['aloo_gobi', 'Aloo gobi'], 2: ['aloo_matar', 'Aloo matar'], 3: ['aloo_methi', 'Aloo methi'], 4: ['aloo_shimla_mirch', 'Aloo shimla mirch'], 5: ['aloo_tikki', 'Aloo tikki'], 6: ['alu_pitika', 'Alu Pitika'], 7: ['amti', 'Amti'], 8: ['anarsa', 'Anarsa'], 9: ['ariselu', 'Ariselu'], 10: ['avial', 'Avial'], 11: ['baingan_fry', 'Baingan Fry'], 12: ['bajri_no_rotlo', 'Bajri no rotlo'], 13: ['balu_shahi', 'Balu shahi'], 14: ['bandar_laddu', 'Bandar laddu'], 15: ['basundi', 'Basundi'], 16: ['bebinca', 'Bebinca'], 17: ['bhakri', 'Bhakri'], 18: ['bhatura', 'Bhatura'], 19: ['bhindi_masala', 'Bhindi masala'], 20: ['biryani', 'Biryani'], 21: ['bisi_bele_bath', 'Bisi bele bath'], 22: ['black_rice', 'Black rice'], 23: ['bombil_fry', 'Bombil fry'], 24: ['brown_rice', 'Brown Rice'], 25: ['butter_chicken', 'Butter chicken'], 26: ['chak_hao_kheer', 'Chak Hao Kheer'], 27: ['chakali', 'Chakali'], 28: ['cham_cham', 'Cham cham'], 29: ['chana_masala', 'Chana masala'], 30: ['chapati', 'Chapati'], 31: ['chevdo', 'Chevdo'], 32: ['chhena_jalebi', 'Chhena jalebi'], 33: ['chhena_kheeri', 'Chhena kheeri'], 34: ['chhena_poda', 'Chhena poda'], 35: ['chicken_tikka', 'Chicken Tikka'], 36: ['chicken_tikka_masala', 'Chicken Tikka masala'], 37: ['chicken_varuval', 'Chicken Varuval'], 38: ['chicken_razala', 'Chicken razala'], 39: ['chikki', 'Chikki'], 40: ['chingri_bhape', 'Chingri Bhape'], 41: ['chingri_malai_curry', 'Chingri malai curry'], 42: ['chole_bhature', 'Chole bhature'], 43: ['chorafali', 'Chorafali'], 44: ['churma_ladoo', 'Churma Ladoo'], 45: ['daal_dhokli', 'Daal Dhokli'], 46: ['daal_baati_churma', 'Daal baati churma'], 47: ['daal_puri', 'Daal puri'], 48: ['dahi_vada', 'Dahi vada'], 49: ['dal_makhani', 'Dal Makhani'], 50: ['dal_tadka', 'Dal tadka'], 51: ['dalithoy', 'Dalithoy'], 52: ['dharwad_pedha', 'Dharwad pedha'], 53: ['dhokla', 'Dhokla'], 54: ['doodhpak', 'Doodhpak'], 55: ['dosa', 'Dosa'], 56: ['double_ka_meetha', 'Double ka meetha'], 57: ['dudhi_halwa', 'Dudhi halwa'], 58: ['dum_aloo', 'Dum aloo'], 59: ['farsi_puri', 'Farsi Puri'], 60: ['gajar_ka_halwa', 'Gajar ka halwa'], 61: ['gatta_curry', 'Gatta curry'], 62: ['ghevar', 'Ghevar'], 63: ['gud_papdi', 'Gud papdi'], 64: ['gulab_jamun', 'Gulab jamun'], 65: ['halvasan', 'Halvasan'], 66: ['idiappam', 'Idiappam'], 67: ['idli', 'Idli'], 68: ['imarti', 'Imarti'], 69: ['jalebi', 'Jalebi'], 70: ['jeera_aloo', 'Jeera Aloo'], 71: ['kaara_kozhambu', 'Kaara kozhambu'], 72: ['kabiraji', 'Kabiraji'], 73: ['kachori', 'Kachori'], 74: ['kadai_paneer', 'Kadai paneer'], 75: ['kadhi_pakoda', 'Kadhi pakoda'], 76: ['kajjikaya', 'Kajjikaya'], 77: ['kaju_katli', 'Kaju katli'], 78: ['kakinada_khaja', 'Kakinada khaja'], 79: ['kalakand', 'Kalakand'], 80: ['karela_bharta', 'Karela bharta'], 81: ['keerai_kootu', 'Keerai kootu'], 82: ['keerai_masiyal', 'Keerai masiyal'], 83: ['keerai_poriyal', 'Keerai poriyal'], 84: ['keerai_sadam', 'Keerai sadam'], 85: ['khakhra', 'Khakhra'], 86: ['khaman', 'Khaman'], 87: ['khandvi', 'Khandvi'], 88: ['kheer', 'Kheer'], 89: ['khichdi', 'Khichdi'], 90: ['khichu', 'Khichu'], 91: ['khorisa', 'Khorisa'], 92: ['kofta', 'Kofta'], 93: ['koldil_chicken', 'Koldil Chicken'], 94: ['kombdi_vade', 'Kombdi vade'], 95: ['kootu', 'Kootu'], 96: ['koshambri', 'Koshambri'], 97: ['koshimbir', 'Koshimbir'], 98: ['kothamali_sadam', 'Kothamali sadam'], 99: ['kuzhambu', 'Kuzhambu'], 100: ['kuzhi_paniyaram', 'Kuzhi paniyaram'], 101: ['laddu', 'Laddu'], 102: ['lassi', 'Lassi'], 103: ['lauki_ke_kofte', 'Lauki ke kofte'], 104: ['lauki_ki_subji', 'Lauki ki subji'], 105: ['lilva_kachori', 'Lilva Kachori'], 106: ['litti_chokha', 'Litti chokha'], 107: ['luchi', 'Luchi'], 108: ['lyangcha', 'Lyangcha'], 109: ['maach_jhol', 'Maach Jhol'], 110: ['mag_dhokli', 'Mag Dhokli'], 111: ['mahim_halwa', 'Mahim halwa'], 112: ['makki_di_roti_sarson_da_saag', 'Makki di roti sarson da saag'], 113: ['malapua', 'Malapua'], 114: ['masala_dosa', 'Masala Dosa'], 115: ['masor_tenga', 'Masor tenga'], 116: ['mawa_bat ...

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import load_model

# %%
test_data_dir = 'test'

test_datagen = ImageDataGenerator(rescale=1. / 255)

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(224, 224),
    batch_size=32
)
# Out:
# Found 3332 images belonging to 200 classes.

# %%
path_to_model='model_v3_inceptionV3_200.h5'
print("Loading the model..")
model = load_model(path_to_model)
print("Done!")
# Out:
# Loading the model..
# Done!

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import itertools
import pandas as pd
import os
import numpy as np
from keras.preprocessing import image

img_width, img_height = 224, 224

def labels_confusion_matrix():
    folder_path="test"
    
    mapping={}
    for i,j in enumerate(sorted(os.listdir(folder_path))):
        mapping[j]=i
    
    files=[]
    real=[]
    predicted=[]

    for i in os.listdir(folder_path):
        
        true=os.path.join(folder_path,i)
        true=true.split('\\')[-1]
        true=mapping[true]
        
        for j in os.listdir(os.path.join(folder_path,i)):
            
            img_ = image.load_img(os.path.join(folder_path,i,j), target_size=(img_height, img_width))
            img_array = image.img_to_array(img_)
            img_processed = np.expand_dims(img_array, axis=0) 
            img_processed /= 255.
            prediction = model.predict(img_processed)
            index = np.argmax(prediction)

            predicted.append(index)
            real.append(true)
            
    return (real,predicted)

def print_confusion_matrix(real,predicted):

    cmap="viridis"
    cm_plot_labels = [i for i in range(200)]

    cm = confusion_matrix(y_true=real, y_pred=predicted)

    # Get the number of classes
    num_classes = cm.shape[0]

    # Define a dictionary to store the classes most frequently confused with each class
    class_confusions = {}

    for i in range(num_classes):
        # Find the indices of the classes most frequently confused with class i
        confused_classes_indices = np.where(cm[i] > 0)[0]
        
        # Exclude class i itself from the list of confused classes
        confused_classes_indices = confused_classes_indices[confused_classes_indices != i]
        
        # Get the class names and counts of confusion
        confused_classes = [(category.get(class_index)[1], cm[i, class_index]) for class_index in confused_classes_indices]
        
        # Sort the confused classes by count (most frequent first)
        confused_classes.sort(key=lambda x: x[1], reverse=True)
        
        # Store the result in the dictionary
        class_confusions[i] = confused_classes

    # Print the classes most frequently confused with each class
    for class_id, confused_classes in class_confusions.items():
        print(f"Class {category.get(class_id)[1]} is most frequently confused with:")
        for class_name, count in confused_classes:
            if count > 2:
                print(f"  Class {class_name} - Count: {count}")
        print()

# %%
y_true,y_pred=labels_confusion_matrix()
print_confusion_matrix(y_true,y_pred)

# %%
print_confusion_matrix(y_true,y_pred)
# Out:
# Class Adhirasam is most frequently confused with:
#   Class Ariselu - Count: 3
#
# Class Aloo gobi is most frequently confused with:
#
# Class Aloo matar is most frequently confused with:
#
# Class Aloo methi is most frequently confused with:
#
# Class Aloo shimla mirch is most frequently confused with:
#
# Class Aloo tikki is most frequently confused with:
#
# Class Alu Pitika is most frequently confused with:
#
# Class Amti is most frequently confused with:
#
# Class Anarsa is most frequently confused with:
#
# Class Ariselu is most frequently confused with:
#   Class Adhirasam - Count: 4
#
# Class Avial is most frequently confused with:
#
# Class Baingan Fry is most frequently confused with:
#
# Class Bajri no rotlo is most frequently confused with:
#   Class Bhakri - Count: 6
#
# Class Balu shahi is most frequently confused with:
#
# Class Bandar laddu is most frequently confused with:
#   Class Gulab jamun - Count: 3
#
# Class Basundi is most frequently confused with:
#   Class Phirni - Count: 6
#   Class Kheer - Count: 4
#
# Class Bebinca is most frequently confused with:
#
# Class Bhakri is most frequently confused with:
#
# Class Bhatura is most frequently confused with:
#   Class Chole bhature - Count: 5
#
# Class Bhindi masala is most frequently confused with:
#
# Class Biryani is most frequently confused with:
#
# Class Bisi bele bath is most frequently confused with:
#
# Class Black rice is most frequently confused with:
#
# Class Bombil fry is most frequently confused with:
#
# Class Brown Rice is most frequently confused with:
#
# Class Butter chicken is most frequently confused with:
#
# Class Chak Hao Kheer is most frequently confused with:
#
# Class Chakali is most frequently confused with:
#
# Class Cham cham is most frequently confused with:
#
# Class Chana masala is most frequently confused with:
#   Class Chole bhature - Count: 3
#
# Class Chapati is most frequently confused with:
#
# Class Chevdo is most frequently confused with:
#
# Class Chhena jalebi is most frequently confused with:
#   Class Jalebi - Count: 3
#
# Class Chhena kheeri is most frequently confused with:
#   Class Kheer - Count: 4
#
# Class Chhena poda is most frequently confused with:
#
# Class Chicken Tikka is most frequently confused with:
#
# Class Chicken Tikka masala is most frequently confused with:
#   Class Butter chicken - Count: 3
#
# Class Chicken Varuval is most frequently confused with:
#
# Class Chicken razala is most frequently confused with:
#
# Class Chikki is most frequently confused with:
#
# Class Chingri Bhape is most frequently confused with:
#   Class Koldil Chicken - Count: 3
#
# Class Chingri malai curry is most frequently confused with:
#   Class Chingri Bhape - Count: 3
#
# Class Chole bhature is most frequently confused with:
#
# Class Chorafali is most frequently confused with:
#
# Class Churma Ladoo is most frequently confused with:
#
# Class Daal Dhokli is most frequently confused with:
#   Class Mag Dhokli - Count: 5
#
# Class Daal baati churma is most frequently confused with:
#
# Class Daal puri is most frequently confused with:
#
# Class Dahi vada is most frequently confused with:
#
# Class Dal Makhani is most frequently confused with:
#
# Class Dal tadka is most frequently confused with:
#
# Class Dalithoy is most frequently confused with:
#
# Class Dharwad pedha is most frequently confused with:
#
# Class Dhokla is most frequently confused with:
#   Class Khandvi - Count: 4
#   Class Khaman - Count: 3
#
# Class Doodhpak is most frequently confused with:
#
# Class Dosa is most frequently confused with:
#
# Class Double ka meetha is most frequently confused with:
#
# Class Dudhi halwa is most frequently confused with:
#
# Class Dum aloo is most frequently confused with:
#   Class Lauki ke kofte - Count: 4
#
# Class Farsi Puri is most frequently confused with:
#
# Class Gajar ka halwa is most frequently confused with:
#
# Class Gatta curry is most frequently confused with:
#
# Class Ghevar is most frequently confused with:
#
# Class Gud papdi is most frequently confused with:
#
# Class Gulab jamun is most frequently confused with:
#
# Class Halvasan is most frequently confused with:
#
# Class Idiappam is most frequently confused with:
#
# Class Idli is most frequently confused with:
#
# Class Imarti is most frequently confused with:
#
# Class Jalebi is most frequently confused with:
#   Class Chhena jalebi - Count: 6
#
# Class Jeera Aloo is most frequently confused with:
#
# Class Kaara kozhambu is most frequently confused with:
#   Class Theeyal - Count: 6
#
# Class Kabiraji is most frequently confused with:
#
# Class Kachori is most frequently confused with:
#   Class Kuzhi paniyaram - Count: 4
#   Class Aloo tikki - Count: 3
#
# Class Kadai paneer is most frequently confused with:
#
# Class Kadhi pakoda is most frequently confused with:
#
# Class Kajjikaya is most frequently confused with:
#
# Class Kaju katli is most frequently confused with:
#
# Class Kakinada khaja is most frequently confused with:
#
# Class Kalakand is most frequently confused with:
#
# Class Karela bharta is most frequently confused with:
#
# Class Keerai kootu is most frequently confused with:
#   Class Kootu - Count: 7
#   Class Turiya Patra Vatana sabji - Count: 3
#
# Class Keerai masiyal is most frequently confused with:
#
# Class Keerai poriyal is most frequently confused with:
#   Class Poriyal - Count: 5
#
# Class Keerai sadam is most frequently confused with:
#   Class Puli sadam - Count: 3
#
# Class Khakhra is most frequently confused with:
#
# Class Khaman is most frequently confused with:
#   Class Dhokla - Count: 6
#
# Class Khandvi is most frequently confused with:
#
# Class Kheer is most frequently confused with:
#   Class Phirni - Count: 3
#
# Class Khichdi is most frequently confused with:
#   Class Bisi bele bath - Count: 4
#
# Class Khichu is most frequently confused with:
#
# Class Khorisa is most frequently confused with:
#
# Class Kofta is most frequently confused with:
#   Class Lauki ke kofte - Count: 3
#
# Class Koldil Chicken is most frequently confused with:
#
# Class Kombdi vade is most frequently confused with:
#
# Class Kootu is most frequently confused with:
#
# Class Koshambri is most frequently confused with:
#   Class Koshimbir - Count: 4
#
# Class Koshimbir is most frequently confused with:
#   Class Dahi vada - Count: 3
#
# Class Kothamali sadam is most frequently confused with:
#   Class Dudhi halwa - Count: 3
#
# Class Kuzhambu is most frequently confused with:
#   Class Theeyal - Count: 3
#
# Class Kuzhi paniyaram is most frequently confused with:
#
# Class Laddu is most frequently confused with:
#   Class Churma Ladoo - Count: 5
#
# Class Lassi is most frequently confused with:
#
# Class Lauki ke kofte is most frequently confused with:
#
# Class Lauki ki subji is most frequently confused with:
#
# Class Lilva Kachori is most frequently confused with:
#
# Class Litti chokha is most frequently confused with:
#
# Class Luchi is most frequently confused with:
#
# Class Lyangcha is most frequently confused with:
#
# Class Maach Jhol is most frequently confused with:
#
# Class Mag Dhokli is most frequently confused with:
#
# Class Mahim halwa is most frequently confused with:
#
# Class Makki di roti sarson da saag is most frequently confused with:
#
# Class Malapua is most frequently confused with:
#
# Class Masala Dosa is most frequently confused with:
#   Class Dosa - Count: 5
#
# Class Masor tenga is most frequently confused with:
#
# Class Mawa Bati is most frequently confused with:
#
# Class Methi na Gota is most frequently confused with:
#
# Class Mihidana is most frequently confused with:
#
# Class Misi roti is most frequently confused with:
#
# Class Misti doi is most frequently confused with:
#
# Class Modak is most frequently confused with:
#
# Class Mohanthal is most frequently confused with:
#
# Class Mushroom do pyaza is most frequently confused with:
#
# Class Mushroom matar is most frequently confused with:
#
# Class Muthiya is most frequently confused with:
#
# Class Mysore pak is most frequently confused with:
#   Class Kaju katli - Count: 3
#
# Class Naan is most frequently confused with:
#   Class Chapati - Count: 3
#
# Class Namakpara is most frequently confused with:
#
# Class Nankhatai is most frequently confused with:
#
# Class Navrattan korma is most frequently confused with:
#
# Class Palak paneer is most frequently confused with:
#
# Class Paneer butter masala is most frequently confused with:
#
# Class Paneer tikka masala is most frequently confused with:
#
# Class Pani puri is most frequently confused with:
#
# Class Panjeeri is most frequently confused with:
#
# Class Papad is most frequently confused with:
#
# Class Paruppu sadam is most frequently confused with:
#
# Class Pav Bhaji is most frequently confused with:
#
# Class Petha is most frequently confused with:
#
# Class Phirni is most frequently confused with:
#
# Class Pindi chana is most frequently confused with:
#
# Class Poha is most frequently confused with:
#
# Class Pongal is most frequently confused with:
#
# Class Poornalu is most frequently confused with:
#
# Class Pootharekulu is most frequently confused with:
#
# Class Poriyal is most frequently confused with:
#
# Class Pork Bharta is most frequently confused with:
#
# Class Prawn malai curry is most frequently confused with:
#
# Class Puli sadam is most frequently confused with:
#
# Class Puri Bhaji is most frequently confused with:
#
# Class Puttu is most frequently confused with:
#
# Class Qubani ka meetha is most frequently confused with:
#
# Class Rabri is most frequently confused with:
#   Class Kheer - Count: 3
#   Class Ras malai - Count: 3
#
# Class Rajma chaval is most frequently confused with:
#
# Class Ras malai is most frequently confused with:
#
# Class Rasabali is most frequently confused with:
#
# Class Rasam is most frequently confused with:
#
# Class Rasgulla is most frequently confused with:
#
# Class Red Rice is most frequently confused with:
#   Class Brown Rice - Count: 3
#
# Class Rongi is most frequently confused with:
#
# Class Sabudana Khichadi is most frequently confused with:
#
# Class Sambar is most frequently confused with:
#
# Class Samosa is most frequently confused with:
#
# Class Sandesh is most frequently confused with:
#
# Class Sandige is most frequently confused with:
#
# Class Sattu ki roti is most frequently confused with:
#
# Class Sev khamani is most frequently confused with:
#   Class Poha - Count: 4
#
# Class Sev tameta is most frequently confused with:
#
# Class Sevai is most frequently confused with:
#
# Class Shahi paneer is most frequently confused with:
#   Class Butter chicken - Count: 3
#
# Class Shahi tukra is most frequently confused with:
#
# Class Shankarpali is most frequently confused with:
#
# Class Sheer khurma is most frequently confused with:
#   Class Kheer - Count: 4
#
# Class Sheera is most frequently confused with:
#
# Class Shrikhand is most frequently confused with:
#   Class Misti doi - Count: 3
#
# Class Shufta is most frequently confused with:
#
# Class Shukto is most frequently confused with:
#
# Class Singori is most frequently confused with:
#
# Class Sohan papdi is most frequently confused with:
#
# Class Sukhdi is most frequently confused with:
#
# Class Surnoli is most frequently confused with:
#
# Class Sutar feni is most frequently confused with:
#
# Class Tandoori Chicken is most frequently confused with:
#
# Class Tandoori Fish Tikka is most frequently confused with:
#
# Class Thalipeeth is most frequently confused with:
#
# Class Thayir sadam is most frequently confused with:
#
# Class Theeyal is most frequently confused with:
#
# Class Thepla is most frequently confused with:
#
# Class Til Pitha is most frequently confused with:
#
# Class Turiya Patra Vatana sabji is most frequently confused with:
#
# Class Undhiyu is most frequently confused with:
#
# Class Unni Appam is most frequently confused with:
#   Class Gulab jamun - Count: 3
#
# Class Upma is most frequently confused with:
#   Class Sabudana Khichadi - Count: 3
#
# Class Uttapam is most frequently confused with:
#
# Class Vada is most frequently confused with:
#
# Class Veg Kolhapuri is most frequently confused with:
#
# Class Vegetable jalfrezi is most frequently confused with:
#
# Class Vindaloo is most frequently confused with:
#
# Class Zunka is most frequently confused with:
